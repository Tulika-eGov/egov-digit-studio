# %% [markdown]
# # CRS Data Loader v2
#
# Simple 4-phase workflow for loading CRS master data:
# 1. **Tenant & Branding** - Organization setup and UI customization
# 2. **Boundaries** - Administrative hierarchy (State → District → Block)
# 3. **Common Masters** - Departments, designations, complaint types
# 4. **Employees** - Staff accounts with roles and assignments
#
# ---

# %%
# Cell 1: Setup
from crs_loader import CRSLoader

# %%
# Cell 2: Connect & Login
# Change URL to your DIGIT environment
loader = CRSLoader("http://kong:8000")
loader.login()
# Out:
# Username:  ADMIN
# Password:  ········
# ✅ Authentication successful!
#    User: ADMIN
#    Name: System Administrator
#    Tenant: pg
#    Token: abdb9129-7418-4bf7-9...
# True

# %%
# Cell 3: Phase 1 - Tenant & Branding
loader.load_tenant("templates/Tenant And Branding Master.xlsx")
# Out:
# ============================================================
# PHASE 1: TENANT & BRANDING
# ============================================================
# File: Tenant And Branding Master.xlsx
#
# [1/3] Creating tenants...
#
# [UPLOADING] tenant.tenants
#    Tenant: pg
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/tenant.tenants
# ============================================================
#    [EXISTS] [1/1] pg.citya (HTTP 400)
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 1
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Tenant And Branding Master.xlsx
#    Sheet: Tenant Info
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# [2/3] Creating branding...
# ⚠️ Could not read 'Tenant Branding Deatils' sheet: Worksheet named 'Tenant Branding Deatils' not found
#
# [3/3] Creating localizations...
#
# [UPLOADING] Localization Messages
#    Tenant: pg.citya
#    Total Messages: 1
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 1 messages in batches of 1...
#       ✅ Batch 1/1: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 1
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Tenant & Branding Summary:
#    Created: 1
#    Already existed: 1
#    Failed: 0
# ────────────────────────────────────────
# {'tenants': {'created': 0, 'exists': 1, 'failed': 0, 'errors': []},
#  'branding': None,
#  'localization': {'created': 1,
#   'exists': 0,
#   'failed': 0,
#   'errors': [],
#   'failed_records': []}}

# %%
# Cell 4: Phase 2 - Boundaries
# Note: Use your boundary Excel file (not in templates folder)
loader.load_boundaries("Boundary Master.xlsx", hierarchy_type="ADMIN")
# Out:
# ============================================================
# PHASE 2: BOUNDARIES
# ============================================================
# File: Boundary Master.xlsx
# Hierarchy: ADMIN
#
# [1/2] Uploading boundary file...
# ❌ Upload error: [Errno 2] No such file or directory: 'Boundary Master.xlsx'
#    Failed to upload file
# {'status': 'failed', 'error': 'File upload failed'}

# %%
# Cell 5: Phase 3 - Common Masters
loader.load_common_masters("templates/Common and Complaint Master.xlsx")
# Out:
# ============================================================
# PHASE 3: COMMON MASTERS
# ============================================================
# File: Common and Complaint Master.xlsx
#
# [1/2] Loading departments & designations...
# 📥 Fetching departments from MDMS for tenant: pg
#    ✅ Found 13 department(s)
# 📥 Fetching designations from MDMS for tenant: pg
#    ✅ Found 29 designation(s)
#    Creating 2 departments...
#
# [UPLOADING] common-masters.Department
#    Tenant: pg
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Department
# ============================================================
#    [OK] [1/2] DEPT_36
#    [OK] [2/2] DEPT_37
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Department
#    ⚠️  Sheet 'Department' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#    Creating 2 designations...
#
# [UPLOADING] common-masters.Designation
#    Tenant: pg
#    Records: 2
#    API URL: http://kong:8000/mdms-v2/v2/_create/common-masters.Designation
# ============================================================
#    [OK] [1/2] DESIG_1002
#    [OK] [2/2] DESIG_1003
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Designation
#    ⚠️  Sheet 'Designation' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# [2/2] Loading complaint types...
#    Creating 1 complaint types...
#
# [UPLOADING] RAINMAKER-PGR.ServiceDefs
#    Tenant: pg
#    Records: 1
#    API URL: http://kong:8000/mdms-v2/v2/_create/RAINMAKER-PGR.ServiceDefs
# ============================================================
#    [FAILED] [1/1] TabBroken (HTTP 400)
#    ERROR: extraneous key [menuPathName] is not permitted
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 1
# ============================================================
#
# 📝 Updating Excel file: templates/Common and Complaint Master.xlsx
#    Sheet: Complaint Type
#    ⚠️  Sheet 'Complaint Type' not found - skipping status update
#
# [UPLOADING] Localization Messages
#    Tenant: pg
#    Total Messages: 2
#    API URL: http://kong:8000/localization/messages/v1/_upsert
# ============================================================
#
#    Found 1 locales: en_IN
# ============================================================
#    📤 Locale: en_IN - Uploading 2 messages in batches of 1...
#       ✅ Batch 1/2: 1 messages uploaded
#       ✅ Batch 2/2: 1 messages uploaded
# ============================================================
# [SUMMARY] Created: 2
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 0
# ============================================================
#
# ────────────────────────────────────────
# Common Masters Summary:
#    Created: 4
#    Already existed: 0
#    Failed: 1
# ────────────────────────────────────────
# {'departments': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'designations': {'created': 2, 'exists': 0, 'failed': 0, 'errors': []},
#  'complaint_types': {'created': 0,
#   'exists': 0,
#   'failed': 1,
#   'errors': [{'id': 'TabBroken',
#     'error': 'extraneous key [menuPathName] is not permitted'}]}}

# %%
# Cell 6: Phase 4 - Employees
loader.load_employees("templates/Employee_Master_Dynamic_statea.xlsx")
# Out:
# ============================================================
# PHASE 4: EMPLOYEES
# ============================================================
# File: Employee_Master_Dynamic_statea.xlsx
#
# [1/2] Reading employee data...
# 📥 Fetching departments from MDMS for tenant: pg
#    ✅ Found 15 department(s)
# 📥 Fetching designations from MDMS for tenant: pg
#    ✅ Found 31 designation(s)
# 📥 Fetching roles from MDMS for tenant: pg
#    ✅ Found 22 role(s) from MDMS
#    Found 1 employees
#
# [2/2] Creating employees...
#
# ============================================================
# 🔐 PRE-CHECK: Validating Roles in MDMS
# ============================================================
#
# 🔍 Checking roles in MDMS for tenant: pg
#    ✅ Found 21 existing roles in MDMS
#    ✅ All 20 required roles already exist in MDMS
#
# ============================================================
# [UPLOADING] HRMS Employees
#    Tenant: pg
#    Records: 1
#    API URL: http://kong:8000/egov-hrms/employees/_create
# ============================================================
#    [FAILED] [1/1] SAMPLE_EMPLOYEE (HTTP 400)
#    ERROR: An error occurred while accessing a underlying resource
# ============================================================
# [SUMMARY] Created: 0
# [SUMMARY] Password Updated: 0
# [SUMMARY] Already Exists: 0
# [SUMMARY] Failed: 1
# ============================================================
#
# 📝 Updating Excel file: templates/Employee_Master_Dynamic_statea.xlsx
#    Sheet: Employee Master
#    ✅ Status columns updated successfully!
#    📊 Updated 1 rows
#
# ────────────────────────────────────────
# Employees Summary:
#    Created: 0
#    Already existed: 0
#    Failed: 1
# ────────────────────────────────────────
# {'created': 0,
#  'exists': 0,
#  'failed': 1,
#  'errors': [{'id': 'SAMPLE_EMPLOYEE',
#    'error': 'An error occurred while accessing a underlying resource'}],
#  'password_updated': 0}

# %% [markdown]
# ## MDMS Schema Creation

# %%
loader.load_mdms_schema(
    excel_path="templates/mdms_schema.xlsx",
    target_tenant="pg"
)
# Out:
# ============================================================
# PHASE: MDMS SCHEMA CREATION
# ============================================================
# File: templates/mdms_schema.xlsx
# Sheet: schemas
# Target Tenant: pg
#
# ============================================
# Creating Schema: Studio.ServiceConfiguration
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "90bd1d55-1fb1-4cbc-b88e-043b1f24f81d",
#       "tenantId": "pg",
#       "code": "Studio.ServiceConfiguration",
#       "description": "Studio.ServiceConfiguration",
#       "definition": {
#         "type": "object",
#         "title": "Generated schema for Root",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "bill",
#           "idgen",
#           "inbox",
#           "rules",
#           "access",
#           "fields",
#           "module",
#           "service",
#           "enabled",
#           "payment",
#           "workflow",
#           "apiconfig",
#           "calculator",
#           "localization",
#           "notification"
#         ],
#         "x-unique": [
#           "module",
#           "service"
#         ],
#         "properties": {
#           "id": {
#             "type": "string"
#           },
#           "pdf": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "key",
#                 "type",
#                 "states"
#               ],
#               "properties": {
#                 "key": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "states": {
#                   "type": "array",
#                   "items": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "bill": {
#             "type": "object",
#             "required": [
#               "taxHead",
#               "taxPeriod",
#               "BusinessService"
#             ],
#             "properties": {
#               "taxHead": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "name",
#                     "order",
#                     "isDebit",
#                     "service",
#                     "category",
#                     "isRequired",
#                     "isActualDemand"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "name": {
#                       "type": "string"
#                     },
#                     "order": {
#                       "type": "string"
#                     },
#                     "isDebit": {
#                       "type": "boolean"
#                     },
#                     "service": {
#                       "type": "string"
#                     },
#                     "category": {
#                       "type": "string"
#                     },
#                     "isRequired": {
#                       "type": "boolean"
#                     },
#                     "isActualDemand": {
#                       "type": "boolean"
#                     }
#                   }
#                 }
#               },
#               "taxPeriod": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "toDate",
#                     "service",
#                     "fromDate",
#                     "periodCycle",
#                     "financialYear"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "toDate": {
#                       "type": "number"
#                     },
#                     "service": {
#                       "type": "string"
#                     },
#                     "fromDate": {
#                       "type": "number"
#                     },
#                     "periodCycle": {
#                       "type": "string"
#                     },
#                     "financialYear": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "BusinessService": {
#                 "type": "object",
#                 "required": [
#                   "code",
#                   "businessService",
#                   "demandUpdateTime",
#                   "isAdvanceAllowed",
#                   "minAmountPayable",
#                   "partPaymentAllowed",
#                   "isVoucherCreationEnabled",
#                   "collectionModesNotAllowed"
#                 ],
#                 "properties": {
#                   "code": {
#                     "type": "string"
#                   },
#                   "businessService": {
#                     "type": "string"
#                   },
#                   "demandUpdateTime": {
#                     "type": "number"
#                   },
#                   "isAdvanceAllowed": {
#                     "type": "boolean"
#                   },
#                   "minAmountPayable": {
#                     "type": "number"
#                   },
#                   "partPaymentAllowed": {
#                     "type": "boolean"
#                   },
#                   "isVoucherCreationEnabled": {
#                     "type": "boolean"
#                   },
#                   "collectionModesNotAllowed": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "idgen": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "type",
#                 "format",
#                 "idname"
#               ],
#               "properties": {
#                 "type": {
#                   "type": "string"
#                 },
#                 "format": {
#                   "type": "string"
#                 },
#                 "idname": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "inbox": {
#             "type": "object",
#             "required": [
#               "index",
#               "module",
#               "sortBy",
#               "sourceFilterPathList",
#               "allowedSearchCriteria"
#             ],
#             "properties": {
#               "index": {
#                 "type": "string"
#               },
#               "module": {
#                 "type": "string"
#               },
#               "sortBy": {
#                 "type": "object",
#                 "required": [
#                   "path",
#                   "defaultOrder"
#                 ],
#                 "properties": {
#                   "path": {
#                     "type": "string"
#                   },
#                   "defaultOrder": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "sourceFilterPathList": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "allowedSearchCriteria": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "name",
#                     "path",
#                     "isMandatory"
#                   ],
#                   "properties": {
#                     "name": {
#                       "type": "string"
#                     },
#                     "path": {
#                       "type": "string"
#                     },
#                     "operator": {
#                       "type": "string"
#                     },
#                     "isMandatory": {
#                       "type": "boolean"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "rules": {
#             "type": "object",
#             "required": [
#               "registry",
#               "calculator",
#               "references",
#               "validation"
#             ],
#             "properties": {
#               "registry": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "calculator": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service",
#                   "customFunction"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   },
#                   "customFunction": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "references": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "type",
#                     "service"
#                   ],
#                   "properties": {
#                     "type": {
#                       "type": "string"
#                     },
#                     "service": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "validation": {
#                 "type": "object",
#                 "required": [
#                   "type",
#                   "service",
#                   "schemaCode",
#                   "customFunction"
#                 ],
#                 "properties": {
#                   "type": {
#                     "type": "string"
#                   },
#                   "service": {
#                     "type": "string"
#                   },
#                   "schemaCode": {
#                     "type": "string"
#                   },
#                   "customFunction": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "access": {
#             "type": "object",
#             "required": [
#               "roles"
#             ],
#             "properties": {
#               "roles": {
#                 "type": "object",
#                 "required": [],
#                 "properties": {
#                   "editor": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "viewer": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "creator": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "actions": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "url"
#                   ],
#                   "properties": {
#                     "url": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "fields": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "name",
#                 "type",
#                 "label"
#               ],
#               "properties": {
#                 "name": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "type",
#                     "properties"
#                   ],
#                   "properties": {
#                     "type": {
#                       "type": "string"
#                     },
#                     "properties": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "name",
#                           "type",
#                           "label",
#                           "format",
#                           "schema",
#                           "required",
#                           "reference",
#                           "orderNumber"
#                         ],
#                         "properties": {
#                           "name": {
#                             "type": "string"
#                           },
#                           "type": {
#                             "type": "string"
#                           },
#                           "label": {
#                             "type": "string"
#                           },
#                           "format": {
#                             "type": "string"
#                           },
#                           "schema": {
#                             "type": "string"
#                           },
#                           "required": {
#                             "type": "boolean"
#                           },
#                           "reference": {
#                             "type": "string"
#                           },
#                           "orderNumber": {
#                             "type": "number"
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "label": {
#                   "type": "string"
#                 },
#                 "properties": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "required": [
#                       "name",
#                       "type",
#                       "label",
#                       "format",
#                       "required",
#                       "orderNumber"
#                     ],
#                     "properties": {
#                       "name": {
#                         "type": "string"
#                       },
#                       "type": {
#                         "type": "string"
#                       },
#                       "label": {
#                         "type": "string"
#                       },
#                       "format": {
#                         "type": "string"
#                       },
#                       "schema": {
#                         "type": "string"
#                       },
#                       "required": {
#                         "type": "boolean"
#                       },
#                       "dependsOn": {
#                         "type": "string"
#                       },
#                       "maxLength": {
#                         "type": "number"
#                       },
#                       "minLength": {
#                         "type": "number"
#                       },
#                       "parentKey": {
#                         "type": "string"
#                       },
#                       "reference": {
#                         "type": "string"
#                       },
#                       "validation": {
#                         "type": "object",
#                         "required": [
#                           "regex",
#                           "message"
#                         ],
#                         "properties": {
#                           "regex": {
#                             "type": "string"
#                           },
#                           "message": {
#                             "type": "string"
#                           }
#                         }
#                       },
#                       "orderNumber": {
#                         "type": "number"
#                       },
#                       "defaultValue": {
#                         "type": "string"
#                       },
#                       "dependencies": {
#                         "type": "array",
#                         "items": {
#                           "type": "string"
#                         }
#                       },
#                       "valueExpression": {
#                         "type": "string"
#                       },
#                       "visibilityExpression": {
#                         "type": "string"
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "module": {
#             "type": "string"
#           },
#           "enabled": {
#             "type": "array",
#             "items": {
#               "type": "string"
#             }
#           },
#           "payment": {
#             "type": "object",
#             "required": [
#               "gateway"
#             ],
#             "properties": {
#               "gateway": {
#                 "type": "string"
#               }
#             }
#           },
#           "service": {
#             "type": "string"
#           },
#           "boundary": {
#             "type": "object",
#             "required": [
#               "lowestLevel",
#               "hierarchyType"
#             ],
#             "properties": {
#               "lowestLevel": {
#                 "type": "string"
#               },
#               "hierarchyType": {
#                 "type": "string"
#               }
#             }
#           },
#           "workflow": {
#             "type": "object",
#             "required": [
#               "ACTIVE",
#               "states",
#               "INACTIVE",
#               "business",
#               "businessService",
#               "businessServiceSla"
#             ],
#             "properties": {
#               "ACTIVE": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "states": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "actions",
#                     "isStartState",
#                     "isStateUpdatable",
#                     "isTerminateState",
#                     "docUploadRequired"
#                   ],
#                   "properties": {
#                     "sla": {
#                       "type": [
#                         "number",
#                         "null"
#                       ]
#                     },
#                     "state": {
#                       "type": [
#                         "string",
#                         "null"
#                       ]
#                     },
#                     "actions": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "roles",
#                           "action",
#                           "nextState"
#                         ],
#                         "properties": {
#                           "roles": {
#                             "type": "array",
#                             "items": {
#                               "type": "string"
#                             }
#                           },
#                           "action": {
#                             "type": "string"
#                           },
#                           "nextState": {
#                             "type": "string"
#                           }
#                         }
#                       }
#                     },
#                     "isStartState": {
#                       "type": "boolean"
#                     },
#                     "generateDemandAt": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "isStateUpdatable": {
#                       "type": "boolean"
#                     },
#                     "isTerminateState": {
#                       "type": "boolean"
#                     },
#                     "applicationStatus": {
#                       "type": [
#                         "string",
#                         "null"
#                       ]
#                     },
#                     "docUploadRequired": {
#                       "type": "boolean"
#                     },
#                     "nextActionAfterPayment": {
#                       "type": "string"
#                     },
#                     "triggerParallelWorkflows": {
#                       "type": "array",
#                       "items": {
#                         "type": [
#                           "string",
#                           "null"
#                         ]
#                       }
#                     },
#                     "autoTransitionEnabledStates": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     }
#                   }
#                 }
#               },
#               "INACTIVE": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "business": {
#                 "type": "string"
#               },
#               "businessService": {
#                 "type": "string"
#               },
#               "businessServiceSla": {
#                 "type": "number"
#               }
#             }
#           },
#           "apiconfig": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "host",
#                 "type",
#                 "method",
#                 "service",
#                 "endpoint"
#               ],
#               "properties": {
#                 "host": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "method": {
#                   "type": "string"
#                 },
#                 "service": {
#                   "type": "string"
#                 },
#                 "endpoint": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "applicant": {
#             "type": "object",
#             "required": [
#               "types",
#               "config",
#               "maximum",
#               "minimum"
#             ],
#             "properties": {
#               "types": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               },
#               "config": {
#                 "type": "object",
#                 "required": [
#                   "systemUser",
#                   "systemRoles",
#                   "systemUserType"
#                 ],
#                 "properties": {
#                   "systemUser": {
#                     "type": "boolean"
#                   },
#                   "systemRoles": {
#                     "type": "array",
#                     "items": {
#                       "type": "string"
#                     }
#                   },
#                   "systemUserType": {
#                     "type": "string"
#                   }
#                 }
#               },
#               "maximum": {
#                 "type": "number"
#               },
#               "minimum": {
#                 "type": "number"
#               },
#               "searchby": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [],
#                   "properties": {
#                     "name": {
#                       "type": "string"
#                     },
#                     "path": {
#                       "type": "string"
#                     },
#                     "type": {
#                       "type": "string"
#                     },
#                     "label": {
#                       "type": "string"
#                     },
#                     "format": {
#                       "type": "string"
#                     },
#                     "required": {
#                       "type": "boolean"
#                     },
#                     "maxLength": {
#                       "type": "number"
#                     },
#                     "minLength": {
#                       "type": "number"
#                     },
#                     "validation": {
#                       "type": "object",
#                       "required": [
#                         "regex",
#                         "message"
#                       ],
#                       "properties": {
#                         "regex": {
#                           "type": "string"
#                         },
#                         "message": {
#                           "type": "string"
#                         }
#                       }
#                     },
#                     "orderNumber": {
#                       "type": "number"
#                     }
#                   }
#                 }
#               },
#               "individal": {
#                 "type": "object",
#                 "required": [
#                   "properties"
#                 ],
#                 "properties": {
#                   "properties": {
#                     "type": "array",
#                     "items": {
#                       "type": "object",
#                       "required": [],
#                       "properties": {
#                         "name": {
#                           "type": "string"
#                         },
#                         "path": {
#                           "type": "string"
#                         },
#                         "type": {
#                           "type": "string"
#                         },
#                         "label": {
#                           "type": "string"
#                         },
#                         "format": {
#                           "type": "string"
#                         },
#                         "hidden": {
#                           "type": "boolean"
#                         },
#                         "required": {
#                           "type": "boolean"
#                         },
#                         "maxLength": {
#                           "type": "number"
#                         },
#                         "minLength": {
#                           "type": "number"
#                         },
#                         "validation": {
#                           "type": "object",
#                           "required": [
#                             "regex",
#                             "message"
#                           ],
#                           "properties": {
#                             "regex": {
#                               "type": "string"
#                             },
#                             "message": {
#                               "type": "string"
#                             }
#                           }
#                         },
#                         "orderNumber": {
#                           "type": "number"
#                         }
#                       }
#                     }
#                   }
#                 }
#               },
#               "organisation": {
#                 "type": "object",
#                 "required": [
#                   "properties"
#                 ],
#                 "properties": {
#                   "properties": {
#                     "type": "array",
#                     "items": {
#                       "type": "object",
#                       "required": [],
#                       "properties": {
#                         "name": {
#                           "type": "string"
#                         },
#                         "path": {
#                           "type": "string"
#                         },
#                         "type": {
#                           "type": "string"
#                         },
#                         "label": {
#                           "type": "string"
#                         },
#                         "format": {
#                           "type": "string"
#                         },
#                         "required": {
#                           "type": "boolean"
#                         },
#                         "maxLength": {
#                           "type": "number"
#                         },
#                         "minLength": {
#                           "type": "number"
#                         },
#                         "validation": {
#                           "type": "object",
#                           "required": [
#                             "regex",
#                             "message"
#                           ],
#                           "properties": {
#                             "regex": {
#                               "type": "string"
#                             },
#                             "message": {
#                               "type": "string"
#                             }
#                           }
#                         },
#                         "orderNumber": {
#                           "type": "number"
#                         }
#                       }
#                     }
#                   }
#                 }
#               },
#               "allowLoggedInUser": {
#                 "type": "boolean"
#               }
#             }
#           },
#           "checklist": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "name",
#                 "state"
#               ],
#               "properties": {
#                 "name": {
#                   "type": "string"
#                 },
#                 "state": {
#                   "type": "string"
#                 },
#                 "checklistData": {
#                   "type": "object",
#                   "properties": {
#                     "data": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "required": [
#                           "id",
#                           "key",
#                           "type",
#                           "level",
#                           "title",
#                           "options",
#                           "isActive",
#                           "isRequired"
#                         ],
#                         "properties": {
#                           "id": {
#                             "type": "string"
#                           },
#                           "key": {
#                             "type": "number"
#                           },
#                           "type": {
#                             "type": "object",
#                             "required": [
#                               "code"
#                             ],
#                             "properties": {
#                               "code": {
#                                 "type": "string"
#                               }
#                             }
#                           },
#                           "level": {
#                             "type": "number"
#                           },
#                           "title": {
#                             "type": "string"
#                           },
#                           "value": {
#                             "type": [
#                               "string",
#                               "number",
#                               "array",
#                               "object",
#                               "null"
#                             ]
#                           },
#                           "options": {
#                             "type": "array",
#                             "items": {
#                               "type": "object",
#                               "required": [
#                                 "id",
#                                 "key",
#                                 "label",
#                                 "parentQuestionId"
#                               ],
#                               "properties": {
#                                 "id": {
#                                   "type": "string"
#                                 },
#                                 "key": {
#                                   "type": "number"
#                                 },
#                                 "label": {
#                                   "type": "string"
#                                 },
#                                 "subQuestions": {
#                                   "type": "array",
#                                   "items": {
#                                     "type": "object"
#                                   }
#                                 },
#                                 "optionComment": {
#                                   "type": "boolean"
#                                 },
#                                 "optionDependency": {
#                                   "type": "boolean"
#                                 },
#                                 "parentQuestionId": {
#                                   "type": "string"
#                                 }
#                               },
#                               "additionalProperties": true
#                             }
#                           },
#                           "isActive": {
#                             "type": "boolean"
#                           },
#                           "parentId": {
#                             "type": [
#                               "string",
#                               "null"
#                             ]
#                           },
#                           "isRequired": {
#                             "type": "boolean"
#                           },
#                           "subQuestions": {
#                             "type": "array",
#                             "items": {
#                               "type": "object"
#                             }
#                           }
#                         },
#                         "additionalProperties": true
#                       }
#                     },
#                     "name": {
#                       "type": "string"
#                     },
#                     "isActive": {
#                       "type": "boolean"
#                     },
#                     "description": {
#                       "type": "string"
#                     }
#                   },
#                   "additionalProperties": true
#                 }
#               },
#               "additionalProperties": true
#             },
#             "uniqueItems": true
#           },
#           "documents": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "module"
#               ],
#               "properties": {
#                 "module": {
#                   "type": "string"
#                 },
#                 "actions": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "required": [
#                       "action",
#                       "documents"
#                     ],
#                     "properties": {
#                       "action": {
#                         "type": "string"
#                       },
#                       "assignee": {
#                         "type": "object",
#                         "properties": {
#                           "show": {
#                             "type": "boolean"
#                           },
#                           "isMandatory": {
#                             "type": "boolean"
#                           }
#                         }
#                       },
#                       "comments": {
#                         "type": "object",
#                         "properties": {
#                           "show": {
#                             "type": "boolean"
#                           },
#                           "isMandatory": {
#                             "type": "boolean"
#                           }
#                         }
#                       },
#                       "documents": {
#                         "type": "array",
#                         "items": {
#                           "type": "object",
#                           "required": [
#                             "code",
#                             "name",
#                             "active",
#                             "isMandatory",
#                             "maxSizeInMB",
#                             "maxFilesAllowed",
#                             "allowedFileTypes"
#                           ],
#                           "properties": {
#                             "code": {
#                               "type": "string"
#                             },
#                             "name": {
#                               "type": "string"
#                             },
#                             "active": {
#                               "type": "boolean"
#                             },
#                             "hintText": {
#                               "type": "string"
#                             },
#                             "isMandatory": {
#                               "type": "boolean"
#                             },
#                             "maxSizeInMB": {
#                               "type": "number"
#                             },
#                             "showHintBelow": {
#                               "type": "boolean"
#                             },
#                             "showTextInput": {
#                               "type": "boolean"
#                             },
#                             "templatePDFKey": {
#                               "type": [
#                                 "string",
#                                 "null"
#                               ]
#                             },
#                             "maxFilesAllowed": {
#                               "type": "number"
#                             },
#                             "allowedFileTypes": {
#                               "type": "array",
#                               "items": {
#                                 "type": "string"
#                               }
#                             },
#                             "templateDownloadURL": {
#                               "type": [
#                                 "string",
#                                 "null"
#                               ]
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "bannerLabel": {
#                   "type": "string"
#                 },
#                 "maxSizeInMB": {
#                   "type": "number"
#                 },
#                 "allowedFileTypes": {
#                   "type": "array",
#                   "items": {
#                     "type": "string"
#                   }
#                 }
#               }
#             }
#           },
#           "calculator": {
#             "type": "object",
#             "required": [
#               "type",
#               "billingSlabs"
#             ],
#             "properties": {
#               "type": {
#                 "type": "string"
#               },
#               "billingSlabs": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "key",
#                     "value"
#                   ],
#                   "properties": {
#                     "key": {
#                       "type": "string"
#                     },
#                     "value": {
#                       "type": "number"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "localization": {
#             "type": "object",
#             "required": [
#               "modules"
#             ],
#             "properties": {
#               "modules": {
#                 "type": "array",
#                 "items": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "notification": {
#             "type": "object",
#             "required": [
#               "sms",
#               "email"
#             ],
#             "properties": {
#               "sms": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "states",
#                     "template"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "states": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "template": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               },
#               "email": {
#                 "type": "array",
#                 "items": {
#                   "type": "object",
#                   "required": [
#                     "code",
#                     "states",
#                     "template"
#                   ],
#                   "properties": {
#                     "code": {
#                       "type": "string"
#                     },
#                     "states": {
#                       "type": "array",
#                       "items": {
#                         "type": "string"
#                       }
#                     },
#                     "subject": {
#                       "type": "string"
#                     },
#                     "template": {
#                       "type": "string"
#                     }
#                   }
#                 }
#               }
#             }
#           },
#           "extendedFromSVC": {
#             "type": "string"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778743970865,
#         "lastModifiedTime": 1778743970865
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: Studio.ServiceConfigurationDrafts
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "00f58fec-7fcd-46c0-87c2-3ad37c810000",
#       "tenantId": "pg",
#       "code": "Studio.ServiceConfigurationDrafts",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "title": "Studio Service Configuration Draft",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "module",
#           "service"
#         ],
#         "x-unique": [
#           "module",
#           "service"
#         ],
#         "properties": {
#           "id": {
#             "type": "string"
#           },
#           "pdf": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "bill": {
#             "type": "object"
#           },
#           "idgen": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "inbox": {
#             "type": "object"
#           },
#           "rules": {
#             "type": "object"
#           },
#           "access": {
#             "type": "object"
#           },
#           "fields": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "module": {
#             "type": "string"
#           },
#           "enabled": {
#             "type": "array",
#             "items": {
#               "type": "string"
#             }
#           },
#           "payment": {
#             "type": "object"
#           },
#           "service": {
#             "type": "string"
#           },
#           "uiforms": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "formName": {
#                   "type": "string"
#                 },
#                 "isActive": {
#                   "type": "boolean"
#                 },
#                 "formConfig": {
#                   "type": "object",
#                   "properties": {
#                     "screens": {
#                       "type": "array",
#                       "items": {
#                         "type": "object",
#                         "properties": {
#                           "name": {
#                             "type": "string"
#                           },
#                           "cards": {
#                             "type": "array",
#                             "items": {
#                               "type": "object"
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "localization": {
#                   "type": "object"
#                 },
#                 "formDescription": {
#                   "type": "string"
#                 }
#               }
#             }
#           },
#           "uiroles": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "id": {
#                   "type": "integer"
#                 },
#                 "code": {
#                   "type": "string"
#                 },
#                 "active": {
#                   "type": "boolean"
#                 },
#                 "category": {
#                   "type": "string"
#                 },
#                 "description": {
#                   "type": "string"
#                 },
#                 "additionalDetails": {
#                   "type": "object"
#                 }
#               }
#             }
#           },
#           "boundary": {
#             "type": "object"
#           },
#           "workflow": {
#             "type": "object"
#           },
#           "apiconfig": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "applicant": {
#             "type": "object"
#           },
#           "documents": {
#             "type": "array",
#             "items": {
#               "type": "object"
#             }
#           },
#           "calculator": {
#             "type": "object"
#           },
#           "uiworkflow": {
#             "type": "object"
#           },
#           "localization": {
#             "type": "object"
#           },
#           "notification": {
#             "type": "object"
#           },
#           "uichecklists": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "data": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "properties": {
#                       "id": {
#                         "type": "string"
#                       },
#                       "key": {
#                         "type": "number"
#                       },
#                       "type": {
#                         "type": "object",
#                         "properties": {
#                           "code": {
#                             "type": "string"
#                           }
#                         }
#                       },
#                       "level": {
#                         "type": "number"
#                       },
# ...
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: DataSecurity.MaskingPatterns
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: DataSecurity.EncryptionPolicy
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: DataSecurity.DecryptionABAC
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: commonUiConfig.PrivacyPolicy
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "d6c9750f-1880-4ac3-8616-d6cb9b75055f",
#       "tenantId": "pg",
#       "code": "commonUiConfig.PrivacyPolicy",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "title": "Generated schema for Root",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "header",
#           "module"
#         ],
#         "x-unique": [
#           "module"
#         ],
#         "properties": {
#           "header": {
#             "type": "string"
#           },
#           "module": {
#             "type": "string"
#           },
#           "contents": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "properties": {
#                 "header": {
#                   "type": "string"
#                 },
#                 "descriptions": {
#                   "type": "array",
#                   "items": {
#                     "type": "object",
#                     "properties": {
#                       "text": {
#                         "type": "string"
#                       },
#                       "type": {
#                         "type": "string"
#                       },
#                       "isBold": {
#                         "type": "boolean"
#                       },
#                       "subDescriptions": {
#                         "type": "array",
#                         "items": {
#                           "type": "object",
#                           "properties": {
#                             "text": {
#                               "type": "string"
#                             },
#                             "type": {
#                               "type": "string"
#                             },
#                             "isBold": {
#                               "type": "boolean"
#                             },
#                             "isSpaceRequired": {
#                               "type": "boolean"
#                             }
#                           }
#                         }
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778743971341,
#         "lastModifiedTime": 1778743971341
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: commonUiConfig.LoginConfig
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "00fd793f-b230-4ce4-ad2c-0bb50643f1e5",
#       "tenantId": "pg",
#       "code": "commonUiConfig.LoginConfig",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "title": "Generated schema for Root",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "title"
#         ],
#         "x-unique": [
#           "title"
#         ],
#         "properties": {
#           "texts": {
#             "type": "object",
#             "required": [
#               "header",
#               "submitButtonLabel",
#               "secondaryButtonLabel"
#             ],
#             "properties": {
#               "header": {
#                 "type": "string"
#               },
#               "submitButtonLabel": {
#                 "type": "string"
#               },
#               "secondaryButtonLabel": {
#                 "type": "string"
#               }
#             }
#           },
#           "title": {
#             "type": "string"
#           },
#           "inputs": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "type",
#                 "key",
#                 "isMandatory",
#                 "populators"
#               ],
#               "properties": {
#                 "key": {
#                   "type": "string"
#                 },
#                 "type": {
#                   "type": "string"
#                 },
#                 "label": {
#                   "type": "string"
#                 },
#                 "disable": {
#                   "type": "boolean"
#                 },
#                 "component": {
#                   "type": "string"
#                 },
#                 "populators": {
#                   "type": "object",
#                   "required": [
#                     "name"
#                   ],
#                   "properties": {
#                     "name": {
#                       "type": "string"
#                     },
#                     "error": {
#                       "type": "string"
#                     },
#                     "mdmsConfig": {
#                       "type": "object",
#                       "required": [
#                         "masterName",
#                         "moduleName",
#                         "localePrefix",
#                         "select"
#                       ],
#                       "properties": {
#                         "select": {
#                           "type": "string"
#                         },
#                         "masterName": {
#                           "type": "string"
#                         },
#                         "moduleName": {
#                           "type": "string"
#                         },
#                         "localePrefix": {
#                           "type": "string"
#                         }
#                       }
#                     },
#                     "optionsKey": {
#                       "type": "string"
#                     },
#                     "validation": {
#                       "type": "object",
#                       "required": [
#                         "required"
#                       ],
#                       "properties": {
#                         "required": {
#                           "type": "boolean"
#                         }
#                       }
#                     }
#                   }
#                 },
#                 "customProps": {
#                   "type": "object",
#                   "required": [
#                     "module"
#                   ],
#                   "properties": {
#                     "module": {
#                       "type": "string"
#                     }
#                   }
#                 },
#                 "isMandatory": {
#                   "type": "boolean"
#                 },
#                 "withoutLabel": {
#                   "type": "boolean"
#                 }
#               }
#             }
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778743971352,
#         "lastModifiedTime": 1778743971352
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: commonUiConfig.HelpTutorial
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "9a99d8eb-017b-4358-9085-65a61af353dc",
#       "tenantId": "pg",
#       "code": "commonUiConfig.HelpTutorial",
#       "description": null,
#       "definition": {
#         "type": "object",
#         "title": "Generated schema for Root",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "module",
#           "helpContent"
#         ],
#         "x-unique": [
#           "module"
#         ],
#         "properties": {
#           "module": {
#             "type": "string"
#           },
#           "helpContent": {
#             "type": "array",
#             "items": {
#               "type": "object",
#               "required": [
#                 "url",
#                 "title",
#                 "icon"
#               ],
#               "properties": {
#                 "url": {
#                   "type": "string"
#                 },
#                 "icon": {
#                   "type": "string"
#                 },
#                 "order": {
#                   "type": "number"
#                 },
#                 "pages": {
#                   "type": "array",
#                   "items": {
#                     "type": "string"
#                   }
#                 },
#                 "title": {
#                   "type": "string"
#                 },
#                 "actionText": {
#                   "type": "string"
#                 },
#                 "iconBackground": {
#                   "type": "string"
#                 }
#               }
#             }
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778743971361,
#         "lastModifiedTime": 1778743971361
#       }
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.StateInfo
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.IdFormat
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.GenderType
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.Designation
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: common-masters.Department
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ROLES.roles
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ROLEACTIONS.roleactions
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: ACCESSCONTROL-ACTIONS-TEST.actions-test
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: tenant.citymodule
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: tenant.tenants
# ============================================
# Status: 400
# {
#   "ResponseInfo": null,
#   "Errors": [
#     {
#       "id": null,
#       "parentId": null,
#       "code": "DUPLICATE_SCHEMA_CODE",
#       "message": "Schema code already exists",
#       "description": null,
#       "params": null
#     }
#   ]
# }
#
# ============================================
# Creating Schema: egov-hrms.EmployeeDepartment
# ============================================
# Status: 202
# {
#   "ResponseInfo": {
#     "apiId": "asset-services",
#     "ver": null,
#     "ts": null,
#     "resMsgId": "uief87324",
#     "msgId": "mdms-schema-create",
#     "status": "successful"
#   },
#   "SchemaDefinitions": [
#     {
#       "id": "45ee1a1b-d907-45a9-aa47-2491e2146dd8",
#       "tenantId": "pg",
#       "code": "egov-hrms.EmployeeDepartment",
#       "description": "HRMS Employee Department ",
#       "definition": {
#         "type": "object",
#         "$schema": "http://json-schema.org/draft-07/schema#",
#         "required": [
#           "code"
#         ],
#         "x-unique": [
#           "code"
#         ],
#         "properties": {
#           "code": {
#             "type": "string"
#           },
#           "active": {
#             "type": "boolean"
#           }
#         }
#       },
#       "isActive": true,
#       "auditDetails": {
#         "createdBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "lastModifiedBy": "dc71bb18-4bb9-4f26-8746-56f6c68cd48a",
#         "createdTime": 1778743971525,
#         "lastModifiedTime": 1778743971525
#       }
#     }
#   ]
# }
#
# ────────────────────────────────────────
# MDMS Schema Summary
# Created: 16
# Failed: 27
# ────────────────────────────────────────
# {'created': 16, 'failed': 27}

# %% [markdown]
# ## MDMS Data Load

# %%
loader.load_mdms_data(
    excel_path="templates/mdms_data.xlsx",
    target_tenant="pg"
)
# Out:
# ============================================================
# PHASE: MDMS DATA CREATION
# ============================================================
# File: templates/mdms_data.xlsx
# Sheet: data
# Target Tenant: pg
# Skipping invalid mdms row 190: the JSON object must be str, bytes or bytearray, not float
# Skipping invalid mdms row 191: the JSON object must be str, bytes or bytearray, not float
#
# ────────────────────────────────────────
# MDMS Data Summary
# Created: 0
# Failed: 0
# ────────────────────────────────────────
# {'created': 0, 'failed': 0}

# %% [markdown]
# ## Phase 5: Localizations
#
# Load bulk localization messages for a new language. Use this when you need to add Hindi, Tamil, Punjabi, or other regional languages.
#
# **Prerequisites:**
# - You need a localization Excel file with a `Localization` sheet
# - Required columns: `Code`, `Message`, `Locale` (e.g., `hi_IN`, `pa_IN`)
# - Optional columns: `Module`
#
# **To add a new language:**
# 1. Get the localization template from `templates/localization.xlsx`
# 2. Fill in translations for the new locale
# 3. Run the cell below with `language_label` and `locale_code` to enable the language in the UI dropdown

# %%
# Phase 5 - Localizations
# For bulk translations - upload localization Excel with translated messages

# Option A: Just upload messages (no new language in dropdown)
loader.load_localizations("templates/localization.xlsx", target_tenant="pg")

# Option B: Upload messages AND enable new language in UI dropdown
# Uncomment and edit the values below:

# loader.load_localizations(
#     "templates/localization.xlsx",
#     target_tenant=TARGET_TENANT,
#     language_label="ਪੰਜਾਬੀ",   # Display name in UI (e.g., "Hindi", "ਪੰਜਾਬੀ", "తెలుగు")
#     locale_code="pa_IN"         # Locale code (e.g., "hi_IN", "pa_IN", "te_IN")
# )
# Out:
# ============================================================
# PHASE 5: LOCALIZATIONS
# ============================================================
# File: localization.xlsx
#
# [1/2] Reading localization data...
#    Found 1163 messages
#    - en_IN: 1163 messages
#
# [2/2] Uploading localization messages...
